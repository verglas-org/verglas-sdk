# %% [markdown]
# # Stream records from an existing Durable Object
# This notebook reads one named source object, then appends its records to a Verglas Stream.

# %%
# %do SENSOR_SOURCE station-42 GET /samples as source
rows = source["records"]
result = {"source_rows": len(rows)}

# %%
# %stream SENSOR_RAW rows
result = {"streamed_rows": len(rows), "stream": "sensor-raw"}
